# %% [markdown]
# <a href="https://colab.research.google.com/github/Rog10/SQL/blob/main/SQL_HW_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Join the film to the film_actor table.
# ![Screen Shot 2022-08-15 at 10.33.42 PM.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Join the actor table to the film_actor table.
# ![Screen Shot 2022-08-15 at 10.35.20 PM.png](data:image/png;base64,...)

# %% [markdown]
# # 3. Try to join the actor, film_actor, and film table together (3 joins!)
# ![Screen Shot 2022-08-15 at 10.37.15 PM.png](data:image/png;base64,...)
