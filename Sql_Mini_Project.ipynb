# %% [markdown]
# <a href="https://colab.research.google.com/github/Rog10/SQL/blob/main/Sql_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Create a table with the following parameters:
# ![Screen Shot 2022-08-15 at 9.33.50 PM.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Insert 3 rows of data into these columns using INSERT. The data you insert should make sense for the column.
# ![Screen Shot 2022-08-15 at 9.36.40 PM.png](data:image/png;base64,...)

# %% [markdown]
# #3. Use an UPDATE to modify any portion of the data.
# ![Screen Shot 2022-08-15 at 9.38.04 PM.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Finally, write a statement to delete one row of data.
# ![Screen Shot 2022-08-15 at 9.39.07 PM.png](data:image/png;base64,...)

# %% [markdown]
# # 1. First you have to create a table than upload the data ,safe the table in to your Laptop and change thepath accordingly.usr the following link for creating table.
# ![Screen Shot 2022-08-15 at 9.40.19 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-08-15 at 9.41.42 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-08-15 at 9.42.17 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-08-15 at 9.43.28 PM.png](data:image/png;base64,...)

# %% [markdown]
# # 2. attached data set (Student_data and Student_marks ) answer the following questions:
# # -- Student with the highest marks in Unit 4
# # -- Find students scored between 89 and 100 Unit 4
#
# ![Screen Shot 2022-08-15 at 9.44.41 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-08-15 at 9.45.32 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Open ended questions:
# # -- Take a closer look at the tables that you created and come up with 10 different scenarios/questions and form SQL
# # -- Ask your colleagues
# ![Screen Shot 2022-08-15 at 9.47.27 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-08-15 at 9.50.52 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-08-15 at 9.52.00 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-08-15 at 9.53.17 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-08-15 at 9.53.59 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-08-15 at 9.55.25 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-08-15 at 9.56.46 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-08-15 at 9.57.30 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-08-15 at 9.58.17 PM.png](data:image/png;base64,...)
